# %% [markdown]
# # Monte Carlo Evaluation of the Standard Optimizer in Python: Probit

# %%
# This code tests scipy.optimize with a standard probit model.
# Everything is properly specified, so the model should cleanly converge.
# Analytic first derivatives are used with BFGS.
# reps is the number of replications.
# obs is the number of observations per replication.
# params is number of regressors and set at two to review results with readprobit.py.  A constant is automatically added.
# tol is the tolerance passed to the optimizer.
# The issue is that as the sample size grows, the LV scales upward, which causes the optimization to terminate prematurely.

import numpy as np
import statsmodels.api as sm
import pandas as pd
from scipy.optimize import minimize
from scipy import stats

# %%
reps = 1000

results = np.zeros((reps, 7))

for i in range(reps):

    obs = 100000
    params = 2
    tol = 1e-03

    params = params + 1
    beta = np.random.normal(0, 1, (params, 1))
    beta0 = np.zeros((params, 1))
    X = np.random.normal(0, 1, (obs, params-1))
    X = sm.add_constant(X)
    ystar = np.dot(X, beta) + np.random.normal(0, 100, (obs, 1))
    y = np.zeros((obs, 1))

    for j in range(obs-1):
        if ystar[j] >= 0:
            y[j] += 1

    def probit(b, y, X, obs, params):
        bv = b.view()
        bv.shape = params, 1
        s = 2 * y - 1
        return -np.sum(stats.norm.logcdf(s * np.dot(X, bv)))

    def probit_grad(b, y, X, obs, params):
        bv = b.view()
        bv.shape = params, 1
        imrp = stats.norm.pdf(np.dot(X, bv))/stats.norm.cdf(np.dot(X, bv))
        imrn = stats.norm.pdf(-np.dot(X, bv))/stats.norm.cdf(-np.dot(X, bv))
        foc = -np.sum(X * (y * imrp - (1 - y) * imrn), axis=0)
        return np.array(foc)

    res = minimize(probit, beta0, args=(y, X, obs, params), method='BFGS',
                   jac=probit_grad, options={'disp': True, 'maxiter':10000},
                   tol=tol)

    zero = res.x[0] - beta[0, 0]
    one = res.x[1] - beta[1, 0]
    two = res.x[2] - beta[2, 0]
    sumd = np.sum(y, axis=0)/obs

    results[i] = i+1, res.success, sumd, zero, one, two, -res.fun
# Out:
# Optimization terminated successfully.
#          Current function value: 69310.832171
#          Iterations: 6
#          Function evaluations: 13
#          Gradient evaluations: 13
# Optimization terminated successfully.
#          Current function value: 69288.832899
#          Iterations: 5
#          Function evaluations: 11
#          Gradient evaluations: 11
# Optimization terminated successfully.
#          Current function value: 69307.265010
#          Iterations: 6
#          Function evaluations: 12
#          Gradient evaluations: 12
# Optimization terminated successfully.
#          Current function value: 69308.573483
#          Iterations: 6
#          Function evaluations: 13
#          Gradient evaluations: 13
# Optimization terminated successfully.
#          Current function value: 69267.781281
#          Iterations: 6
#          Function evaluations: 13
#          Gradient evaluations: 13
# Optimization terminated successfully.
#          Current function value: 69313.942730
#          Iterations: 5
#          Function evaluations: 13
#          Gradient evaluations: 13
# Optimization terminated successfully.
#          Current function value: 69300.485191
#          Iterations: 5
#          Function evaluations: 13
#          Gradient evaluations: 13
# Optimization terminated successfully.
#          Current function value: 69310.992310
#          Iterations: 6
#          Function evaluations: 13
#          Gradient evaluations: 13
# Optimization terminated successfully.
#          Current function value: 69277.827446
#          Iterations: 5
#          Function evaluations: 15
#          Gradient evaluations: 15
# Optimization terminated successfully.
#          Current function value: 69311.472216
#          Iterations: 7
#          Function evaluations: 14
#          Gradient evaluations: 14
# Optimization terminated successfully.
#          Current function value: 69307.265824
#          Iterations: 7
#          Function evaluations: 13
#          Gradient evaluations: 13
# Optimization terminated successfully.
#          Current function value: 69306.549813
#          Iterations: 5
#          Function evaluations: 13
#          Gradient evaluations: 13
# Optimization terminated successfully.
#          Current function value: 69311.720439
#          Iterations: 5
#          Function evaluations: 13
#          Gradient evaluations: 13
# Optimization terminated successfully.
#          Current function value: 69305.715554
#          Iterations: 5
#          Function evaluations: 11
#          Gradient evaluations: 11
# Optimization terminated successfully.
#          Current function value: 69306.045502
#          Iterations: 7
#          Function evaluations: 12
#          Gradient evaluations: 12
# Optimization terminated successfully.
#          Current function value: 69286.947247
#          Iterations: 6
#          Function evaluations: 10
#          Gradient evaluations: 10
# Optimization terminated successfully.
#          Current function value: 69312.697957
#          Iterations: 7
#          Function evaluations: 14
#          Gradient evaluations: 14
# Optimization terminated successfully.
#          Current function value: 69297.606556
#          Iterations: 6
#          Function evaluations: 14
#          Gradient evaluations: 14
# Optimization terminated successfully.
#          Current function value: 69301.328457
#          Iterations: 6
#          Function evaluations: 11
#          Gradient evaluations: 11
# Optimization terminated successfully.
#          Current function value: 69310.114640
#          Iterations: 6
#          Function evaluations: 11
#          Gradient evaluations: 11
# Optimization terminated successfully.
#          Current function value: 69292.031013
#          Iterations: 6
#          Function evaluations: 10
#          Gradient evaluations: 10
# Optimization terminated successfully.
#          Current function value: 69302.773680
#          Iterations: 6
#          Function evaluations: 11
#          Gradient evaluations: 11
# Optimization terminated successfully.
#          Current function value: 69308.909517
#          Iterations: 7
#          Function evaluations: 15
#          Gradient evaluations: 15
# Optimization terminated successfully.
#          Current function value: 69310.874921
#          Iterations: 5
#          Function evaluations: 13
#          Gradient evaluations: 13
# Optimization terminated successfully.
#          Current function value: 69308.579190
#          Iterations: 7
#          Function evaluations: 14
#          Gradient evaluations: 14
# Optimization terminated successfully.
#          Current function value: 69303.379105
#          Iterations: 7
#          Function evaluations: 13
#          Gradient evaluations: 13
# Optimization terminated successfully.
#          Current function value: 69278.913995
#          Iterations: 7
#          Function evaluations: 13
#          Gradient evaluations: 13
# Optimization terminated successfully.
#          Current function value: 69308.863365
#          Iterations: 5
#          Function evaluations: 13
#          Gradient evaluations: 13
# Optimization terminated successfully.
#          Current function value: 69310.635192
#          Iterations: 6
#          Function evaluations: 15
#          Gradient evaluations: 15
# Optimization terminated successfully.
#          Current function value: 69290.573614
#          Iterations: 6
#          Function evaluations: 12
#          Gradient evaluations: 12
# Optimization terminated successfully.
#          Current function value: 69304.533141
#          Iterations: 5
#          Function evaluations: 14
#          Gradient evaluations: 14
# Optimization terminated successfully.
#          Current function value: 69306.289614
#          Iterations: 6
#          Function evaluations: 11
#          Gradient evaluations: 11
# Optimization terminated successfully.
#          Current function value: 69309.595170
#          Iterations: 5
#          Function evaluations: 10
#          Gradient evaluations: 10
# Optimization terminated successfully.
#          Current function value: 69303.026076
#          Iterations: 5
#          Function evaluations: 13
#          Gradient evaluations: 13
# Optimization terminated successfully.
#          Current function value: 69307.225806
#          Iterations: 6
#          Function evaluations: 15
#          Gradient evaluations: 15
# Optimization terminated successfully.
#          Current function value: 69296.058010
#          Iterations: 5
#          Function evaluations: 10
#          Gradient evaluations: 10
# Optimization terminated successfully.
#          Current function value: 69302.673303
#          Iterations: 6
#          Function evaluations: 13
#          Gradient evaluations: 13
# Optimization terminated successfully.
#          Current function value: 69312.011206
#          Iterations: 6
#          Function evaluations: 14
#          Gradient evaluations: 14
# Optimization terminated successfully.
#          Current function value: 69306.900163
#          Iterations: 6
#          Function evaluations: 14
#          Gradient evaluations: 14
# Optimization terminated successfully.
#          Current function value: 69282.327049
#          Iterations: 5
#          Function evaluations: 13
#          Gradient evaluations: 13
# Optimization terminated successfully.
#          Current function value: 69309.677798
#          Iterations: 7
#          Function evaluations: 15
#          Gradient evaluations: 15
# Optimization terminated successfully.
#          Current function value: 69309.016743
#          Iterations: 6
#          Function evaluations: 14
#          Gradient evaluations: 14
# Optimization terminated successfully.
#          Current function value: 69306.771599
#          Iterations: 5
#          Function evaluations: 13
#          Gradient evaluations: 13
# Optimization terminated successfully.
#          Current function value: 69287.875593
#          Iterations: 5
#          Function evaluations: 13
#          Gradient evaluations: 13
# Optimization terminated successfully.
#          Current function value: 69310.101493
#          Iterations: 6
#          Function evaluations: 11
#          Gradient evaluations: 11
# Optimization terminated successfully.
#          Current function value: 69283.428284
#          Iterations: 7
#          Function evaluations: 11
#          Gradient evaluations: 11
# Optimization terminated successfully.
#          Current function value: 69312.879350
#          Iterations: 6
#          Function evaluations: 15
#          Gradient evaluations: 15
# Optimization terminated successfully.
#          Current function value: 69309.845033
#          Iterations: 6
#          Function evaluations: 10
#          Gradient evaluations: 10
# Optimization terminated successfully.
#          Current function value: 69296.441282
#          Iterations: 6
#          Function evaluations: 14
#          Gradient evaluations: 14
# Optimization terminated successfully.
#          Current function value: 69309.467600
#          Iterations: 5
#          Function evaluations: 10
#          Gradient evaluations: 10
# Optimization terminated successfully.
#          Current function value: 69313.734793
#          Iterations: 7
#          Function evaluations: 11
#          Gradient evaluations: 11
# Optimization terminated successfully.
#          Current function value: 69304.242890
#          Iterations: 6
#          Function evaluations: 14
#          Gradient evaluations: 14
# Optimization terminated successfully.
#          Current function value: 69296.805972
#          Iterations: 7
#          Function evaluations: 12
#          Gradient evaluations: 12
# Optimization terminated successfully.
#          Current function value: 69292.807436
#          Iterations: 6
#          Function evaluations: 15
#          Gradient evaluations: 15
# Optimization terminated successfully.
#          Current function value: 69308.901869
#          Iterations: 7
#          Function evaluations: 12
#          Gradient evaluations: 12
# Optimization terminated successfully.
#          Current function value: 69304.292622
#          Iterations: 6
#          Function evaluations: 10
#          Gradient evaluations: 10
# Optimization terminated successfully.
#          Current function value: 69296.875346
#          Iterations: 6
#          Function evaluations: 13
#          Gradient evaluations: 13
# Optimization terminated successfully.
#          Current function value: 69287.970937
#          Iterations: 6
#          Function evaluations: 14
#          Gradient evaluations: 14
# Optimization terminated successfully.
#          Current function value: 69289.204838
#          Iterations: 6
#          Function evaluations: 13
#          Gradient evaluations: 13
# Optimization terminated successfully.
#          Current function value: 69305.053738
#          Iterations: 5
#          Function evaluations: 13
#          Gradient evaluations: 13
# Optimization terminated successfully.
#          Current function value: 69299.268772
#          Iterations: 7
#          Function evaluations: 13
#          Gradient evaluations: 13
# Optimization terminated successfully.
#          Current function value: 69306.163434
#          Iterations: 6
#          Function evaluations: 13
#          Gradient evaluations: 13
# Optimization terminated successfully.
#          Current function value: 69312.241016
#          Iterations: 5
#          Function evaluations: 10
#          Gradient evaluations: 10
# Optimization terminated successfully.
#          Current function value: 69289.510957
#          Iterations: 6
#          Function evaluations: 13
#          Gradient evaluations: 13
# Optimization terminated successfully.
#          Current function value: 69273.317341
#          Iterations: 6
#          Function evaluations: 11
#          Gradient evaluations: 11
# Optimization terminated successfully.
#          Current function value: 69310.604884
#          Iterations: 6
#          Function evaluations: 11
#          Gradient evaluations: 11
# Optimization terminated successfully.
#          Current function value: 69300.436081
#          Iterations: 6
#          Function evaluations: 10
#          Gradient evaluations: 10
# Optimization terminated successfully.
#          Current function value: 69309.639213
#          Iterations: 6
#          Function evaluations: 12
#          Gradient evaluations: 12
# Optimization terminated successfully.
#          Current function value: 69291.532587
#          Iterations: 5
#          Function evaluations: 12
#          Gradient evaluations: 12
# Optimization terminated successfully.
#          Current function value: 69308.200148
#          Iterations: 6
#          Function evaluations: 14
#          Gradient evaluations: 14
# Optimization terminated successfully.
#          Current function value: 69311.162538
#          Iterations: 5
#          Function evaluations: 14
#          Gradient evaluations: 14
# Optimization terminated successfully.
#          Current function value: 69314.322269
#          Iterations: 7
#          Function evaluations: 14
#          Gradient evaluations: 14
# Optimization terminated successfully.
#          Current function value: 69310.430404
#          Iterations: 5
#          Function evaluations: 9
#          Gradient evaluations: 9
# Optimization terminated successfully.
#          Current function value: 69305.642685
#          Iterations: 6
#          Function evaluations: 14
#          Gradient evaluations: 14
# Optimization terminated successfully.
#          Current function value: 69306.283846
#          Iterations: 6
#          Function evaluations: 14
#          Gradient evaluations: 14
# Optimization terminated successfully.
#          Current function value: 69310.475274
#          Iterations: 7
#          Function evaluations: 15
#          Gradient evaluations: 15
# Optimization terminated successfully.
#          Current function value: 69290.800904
#          Iterations: 6
#          Function evaluations: 12
#          Gradient evaluations: 12
# Optimization terminated successfully.
#          Current function value: 69312.556425
#          Iterations: 5
#          Function evaluations: 12
#          Gradient evaluations: 12
# Optimization terminated successfully.
#          Current function value: 69313.141601
#          Iterations: 6
#          Function evaluations: 13
#          Gradient evaluations: 13
# Optimization terminated successfully.
#          Current function value: 69312.299245
#          Iterations: 5
#          Function evaluations: 14
#          Gradient evaluations: 14
# Optimization terminated successfully.
#          Current function value: 69313.453571
#          Iterations: 6
#          Function evaluations: 14
#          Gradient evaluations: 14
# Optimization terminated successfully.
#          Current function value: 69311.268507
#          Iterations: 6
#          Function evaluations: 11
#          Gradient evaluations: 11
# Optimization terminated successfully.
#          Current function value: 69311.580660
#          Iterations: 6
#          Function evaluations: 14
#          Gradient evaluations: 14
# Optimization terminated successfully.
#          Current function value: 69284.291306
#          Iterations: 6
#          Function evaluations: 13
#          Gradient evaluations: 13
# Optimization terminated successfully.
#          Current function value: 69301.933596
#          Iterations: 6
#          Function evaluations: 13
#          Gradient evaluations: 13
# Optimization terminated successfully.
#          Current function value: 69300.329908
#          Iterations: 7
#          Function evaluations: 14
#          Gradient evaluations: 14
# Optimization terminated successfully.
#          Current function value: 69313.161804
#          Iterations: 6
#          Function evaluations: 10
#          Gradient evaluations: 10
# Optimization terminated successfully.
#          Current function value: 69299.014003
#          Iterations: 5
#          Function evaluations: 13
#          Gradient evaluations: 13
# Optimization terminated successfully.
#          Current function value: 69292.856993
#          Iterations: 5
#          Function evaluations: 12
#          Gradient evaluations: 12
# Optimization terminated successfully.
#          Current function value: 69276.717799
#          Iterations: 5
#          Function evaluations: 9
#          Gradient evaluations: 9
# Optimization terminated successfully.
#          Current function value: 69305.075717
#          Iterations: 6
#          Function evaluations: 13
#          Gradient evaluations: 13
# Optimization terminated successfully.
#          Current function value: 
#          Iterations: 6
#          Function evaluations: 14
#          Gradient evaluations: 14
# Optimization terminated successfully.
#          Current function value: 69302.495204
#          Iterations: 6
#          Function evaluations: 14
#          Gradient evaluations: 14
# Optimization terminated successfully.
#          Current function value: 69313.384565
#          Iterations: 5
#          Function evaluations: 14
#          Gradient evaluations: 14
# Optimization terminated successfully.
#          Current function value: 69301.195260
#          Iterations: 6
#          Function evaluations: 11
#          Gradient evaluations: 11
# Optimization terminated successfully.
#          Current function value: 69288.128860
#          Iterations: 6
#          Function evaluations: 15
#          Gradient evaluations: 15
# Optimization terminated successfully.
#          Current function value: 69283.511274
#          Iterations: 7
#          Function evaluations: 12
#          Gradient evaluations: 12
# Optimization terminated successfully.
#          Current function value: 69307.666751
#          Iterations: 5
#          Function evaluations: 12
#          Gradient evaluations: 12
# Optimization terminated successfully.
#          Current function value: 69305.343159
#          Iterations: 6
#          Function evaluations: 13
#          Gradient evaluations: 13
# Optimization terminated successfully.
#          Current function value: 69303.314455
#          Iterations: 6
#          Function evaluations: 15
#          Gradient evaluations: 15
# Optimization terminated successfully.
#          Current function value: 69301.463305
#          Iterations: 6
#          Function evaluations: 11
#          Gradient evaluations: 11
# Optimization terminated successfully.
#          Current function value: 69292.143498
#          Iterations: 6
#          Function evaluations: 11
#          Gradient evaluations: 11
# Optimization terminated successfully.
#          Current function value: 69300.084489
#          Iterations: 6
#          Function evaluations: 12
#          Gradient evaluations: 12
# Optimization terminated successfully.
#          Current function value: 69302.094699
#          Iterations: 5
#          Function evaluations: 9
#          Gradient evaluations: 9
# Optimization terminated successfully.
#          Current function value: 69287.231804
#          Iterations: 6
#          Function evaluations: 13
#          Gradient evaluations: 13
# Optimization terminated successfully.
#          Current function value: 69306.029804
#          Iterations: 6
#          Function evaluations: 15
#          Gradient evaluations: 15
# Optimization terminated successfully.
#          Current function value: 69306.233836
#          Iterations: 6
#          Function evaluations: 14
#          Gradient evaluations: 14
# Optimization terminated successfully.
#          Current function value: 69309.835367
#          Iterations: 6
#          Function evaluations: 14
#          Gradient evaluations: 14
# Optimization terminated successfully.
#          Current function value: 69307.738961
#          Iterations: 5
#          Function evaluations: 13
#          Gradient evaluations: 13
# Optimization terminated successfully.
#          Current function value: 69307.097793
#          Iterations: 7
#          Function evaluations: 13
#          Gradient evaluations: 13
# Optimization terminated successfully.
#          Current function value: 69283.025375
#          Iterations: 6
#          Function evaluations: 13
#          Gradient evaluations: 13
# Optimization terminated successfully.
#          Current function value: 69305.776265
#          Iterations: 6
#          Function evaluations: 14
#          Gradient evaluations: 14
# Optimization terminated successfully.
#          Current function value: 69294.698594
#          Iterations: 6
#          Function evaluations: 12
#          Gradient evaluations: 12
# Optimization terminated successfully.
#          Current function value: 69283.340029
#          Iterations: 6
#          Function evaluations: 13
#          Gradient evaluations: 13
# Optimization terminated successfully.
#          Current function value: 69310.611845
#          Iterations: 6
#          Function evaluations: 10
#          Gradient evaluations: 10
# Optimization terminated successfully.
#          Current function value: 69309.542358
#          Iterations: 6
#          Function evaluations: 14
#          Gradient evaluations: 14
# Optimization terminated successfully.
#          Current function value: 69302.431309
#          Iterations: 6
#          Function evaluations: 12
#          Gradient evaluations: 12
# Optimization terminated successfully.
#          Current function value: 69304.377362
#          Iterations: 7
#          Function evaluations: 14
#          Gradient evaluations: 14
# Optimization terminated successfully.
#          Current function value: 69312.294433
#          Iterations: 6
#          Function evaluations: 12
#          Gradient evaluations: 12
# Optimization terminated successfully.
#          Current function value: 69302.806677
#          Iterations: 7
#          Function evaluations: 12
#          Gradient evaluations: 12
# Optimization terminated successfully.
#          Current function value: 69313.113878
#          Iterations: 6
#          Function evaluations: 13
#          Gradient evaluations: 13
# Optimization terminated successfully.
#          Current function value: 69310.784484
#          Iterations: 6
#          Function evaluations: 11
#          Gradient evaluations: 11
# Optimization terminated successfully.
#          Current function value: 69313.352764
#          Iterations: 6
#          Function evaluations: 14
#          Gradient evaluations: 14
# Optimization terminated successfully.
#          Current function value: 69310.600593
#          Iterations: 7
#          Function evaluations: 11
#          Gradient evaluations: 11
# Optimization terminated successfully.
#          Current function value: 69289.311748
#          Iterations: 6
#          Function evaluations: 11
#          Gradient evaluations: 11
# Optimization terminated successfully.
#          Current function value: 69309.707615
#          Iterations: 5
#          Function evaluations: 14
#          Gradient evaluations: 14
# Optimization terminated successfully.
#          Current function value: 69298.017454
#          Iterations: 6
#          Function evaluations: 14
#          Gradient evaluations: 14
# Optimization terminated successfully.
#          Current function value: 69308.914568
#          Iterations: 7
#          Function evaluations: 12
#          Gradient evaluations: 12
# Optimization terminated successfully.
#          Current function value: 69290.093513
#          Iterations: 6
#          Function evaluations: 13
#          Gradient evaluations: 13
# Optimization terminated successfully.
#          Current function value: 69308.468778
#          Iterations: 6
#          Function evaluations: 11
#          Gradient evaluations: 11
# Optimization terminated successfully.
#          Current function value: 69292.457650
#          Iterations: 6
#          Function evaluations: 11
#          Gradient evaluations: 11
# Optimization terminated successfully.
#          Current function value: 69288.729396
#          Iterations: 5
#          Function evaluations: 9
#          Gradient evaluations: 9
# Optimization terminated successfully.
#          Current function value: 69305.052044
#          Iterations: 6
#          Function evaluations: 14
#          Gradient evaluations: 14
# Optimization terminated successfully.
#          Current function value: 69307.607219
#          Iterations: 5
#          Function evaluations: 10
#          Gradient evaluations: 10
# Optimization terminated successfully.
#          Current function value: 69304.145611
#          Iterations: 6
#          Function evaluations: 12
#          Gradient evaluations: 12
# Optimization terminated successfully.
#          Current function value: 69301.855127
#          Iterations: 5
#          Function evaluations: 12
#          Gradient evaluations: 12
# Optimization terminated successfully.
#          Current function value: 69301.599597
#          Iterations: 7
#          Function evaluations: 15
#          Gradient evaluations: 15
# Optimization terminated successfully.
#          Current function value: 69304.581679
#          Iterations: 7
#          Function evaluations: 14
#          Gradient evaluations: 14
# Optimization terminated successfully.
#          Current function value: 69303.177331
#          Iterations: 5
#          Function evaluations: 9
#          Gradient evaluations: 9
# Optimization terminated successfully.
#          Current function value: 69296.655808
#          Iterations: 6
#          Function evaluations: 13
#          Gradient evaluations: 13
# Optimization terminated successfully.
#          Current function value: 69288.127552
#          Iterations: 6
#          Function evaluations: 13
#          Gradient evaluations: 13
# Optimization terminated successfully.
#          Current function value: 69298.147189
#          Iterations: 5
#          Function evaluations: 11
#          Gradient evaluations: 11
# Optimization terminated successfully.
#          Current function value: 69294.751211
#          Iterations: 7
#          Function evaluations: 12
#          Gradient evaluations: 12

# %%
data = pd.DataFrame(results)
data.columns = ['rep', 'success', 'aved', 'one', 'two', 'three', 'llv']
data.head()
# Out:
#    rep  success     aved       one       two     three           llv
# 0  1.0      1.0  0.49844  0.341819 -0.823334  1.581244 -69310.832171
# 1  2.0      1.0  0.50711 -1.352328  1.073425  1.235598 -69288.832899
# 2  3.0      1.0  0.49772  0.648455 -0.545069  0.104266 -69307.265010
# 3  4.0      1.0  0.50129 -0.182768  0.559335 -1.679309 -69308.573483
# 4  5.0      1.0  0.51133 -2.179565  0.708885  2.703355 -69267.781281

# %%
data1 = data[data['success'] == 1]
data0 = data[data['success'] == 0]

print(data1.describe())
print(data0.describe())
# Out:
#                rep  success        aved         one         two       three  \
# count   997.000000    997.0  997.000000  997.000000  997.000000  997.000000
# mean    500.297894      1.0    0.500210   -0.041634   -0.033900   -0.024680
# std     289.194322      0.0    0.004388    1.013782    1.029765    0.986207
# min       1.000000      1.0    0.487920   -2.959941   -3.468056   -2.718760
# 25%     250.000000      1.0    0.497020   -0.764187   -0.783347   -0.690058
# 50%     500.000000      1.0    0.500270   -0.035229   -0.025270   -0.048157
# 75%     751.000000      1.0    0.503390    0.674158    0.659327    0.592610
# max    1000.000000      1.0    0.513840    3.120318    2.954745    3.094910
#
#                 llv
# count    997.000000
# mean  -69303.025070
# std        9.034536
# min   -69314.621366
# 25%   -69309.740476
# 50%   -69305.134959
# 75%   -69298.940614
# max   -69255.038643
#               rep  success      aved       one       two     three  \
# count    3.000000      3.0  3.000000  3.000000  3.000000  3.000000
# mean   567.666667      0.0  0.503477 -0.790956  0.367527 -0.020908
# std    102.109418      0.0  0.010383  1.977638  0.286352  2.455412
# min    450.000000      0.0  0.491960 -2.498904  0.166693 -1.534173
# 25%    535.000000      0.0  0.499155 -1.874304  0.203579 -1.437440
# 50%    620.000000      0.0  0.506350 -1.249703  0.240465 -1.340706
# 75%    626.500000      0.0  0.509235  0.063018  0.467944  0.735725
# max    633.000000      0.0  0.512120  1.375739  0.695423  2.812157
#
#                 llv
# count      3.000000
# mean  -69277.639221
# std        9.653007
# min   -69283.427635
# 25%   -69283.210984
# 50%   -69282.994333
# 75%   -69274.745015
# max   -69266.495697
