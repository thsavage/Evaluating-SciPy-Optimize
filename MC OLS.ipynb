# %% [markdown]
# # Monte Carlo Evaluation of the Standard Optimizer in Python: OLS

# %%
# This code tests scipy.optimize with a standard OLS.
# Everything is properly specified, so the model should cleanly converge.
# Analytic first derivatives are used with BFGS.
# reps is the number of replications.
# obs is the number of observations per replication.
# params is number of regressors and set at two to review results with readprobit.py.  A constant is automatically added.
# tol is the tolerance passed to the optimizer.
# The issue is that as the sample size grows, the LV scales upward, which causes the optimization to terminate prematurely.

import numpy as np
import statsmodels.api as sm
import pandas as pd
from scipy.optimize import minimize
from scipy import stats

# %%
reps = 10000

results = np.zeros((reps, 7))

for i in range(reps):

    obs = 1000000
    params = 2
    tol = 1e-05

    params = params + 1
    beta = np.random.normal(0, 1, (params, 1))
    beta0 = np.zeros((params, 1))
    X = np.random.normal(0, 1, (obs, params-1))
    X = sm.add_constant(X)
    y = np.dot(X, beta) + np.random.normal(0, 1, (obs, 1))

    def ols(b, y, X, obs, params):
        bv = b.view()
        bv.shape = params, 1
        e = y - np.dot(X, bv)
        return np.array(np.sum(e**2))

    def ols_grad(b, y, X, obs, params):
        bv = b.view()
        bv.shape = params, 1
        foc = -np.sum(X * (y - np.dot(X, bv)), axis=0)
        return np.array(foc)

    res = minimize(ols, beta0, args=(y, X, obs, params), method='BFGS',
                   jac=ols_grad, options={'disp': True, 'maxiter':10000},
                   tol=tol)

    zero = res.x[0] - beta[0, 0]
    one = res.x[1] - beta[1, 0]
    two = res.x[2] - beta[2, 0]
    sumd = np.sum(y, axis=0)/obs

    results[i] = i+1, res.success, sumd, zero, one, two, -res.fun
# Out:
# Optimization terminated successfully.
#          Current function value: 997683.910966
#          Iterations: 6
#          Function evaluations: 13
#          Gradient evaluations: 13
# Optimization terminated successfully.
#          Current function value: 1000970.498028
#          Iterations: 6
#          Function evaluations: 14
#          Gradient evaluations: 14
# Optimization terminated successfully.
#          Current function value: 998593.261719
#          Iterations: 7
#          Function evaluations: 17
#          Gradient evaluations: 17
# Optimization terminated successfully.
#          Current function value: 1000219.744942
#          Iterations: 6
#          Function evaluations: 13
#          Gradient evaluations: 13
# Optimization terminated successfully.
#          Current function value: 998850.626671
#          Iterations: 6
#          Function evaluations: 15
#          Gradient evaluations: 15
# Optimization terminated successfully.
#          Current function value: 1002422.004454
#          Iterations: 6
#          Function evaluations: 14
#          Gradient evaluations: 14
# Optimization terminated successfully.
#          Current function value: 999677.229969
#          Iterations: 6
#          Function evaluations: 12
#          Gradient evaluations: 12
# Optimization terminated successfully.
#          Current function value: 998914.730042
#          Iterations: 6
#          Function evaluations: 15
#          Gradient evaluations: 15
# Optimization terminated successfully.
#          Current function value: 1000467.859700
#          Iterations: 6
#          Function evaluations: 14
#          Gradient evaluations: 14
# Optimization terminated successfully.
#          Current function value: 999783.167542
#          Iterations: 6
#          Function evaluations: 14
#          Gradient evaluations: 14
# Optimization terminated successfully.
#          Current function value: 999681.383160
#          Iterations: 6
#          Function evaluations: 13
#          Gradient evaluations: 13
# Optimization terminated successfully.
#          Current function value: 1000823.833375
#          Iterations: 6
#          Function evaluations: 14
#          Gradient evaluations: 14
# Optimization terminated successfully.
#          Current function value: 998744.649896
#          Iterations: 6
#          Function evaluations: 14
#          Gradient evaluations: 14
# Optimization terminated successfully.
#          Current function value: 1001642.342994
#          Iterations: 6
#          Function evaluations: 13
#          Gradient evaluations: 13
# Optimization terminated successfully.
#          Current function value: 998824.136604
#          Iterations: 6
#          Function evaluations: 15
#          Gradient evaluations: 15
# Optimization terminated successfully.
#          Current function value: 1000176.759427
#          Iterations: 6
#          Function evaluations: 13
#          Gradient evaluations: 13
# Optimization terminated successfully.
#          Current function value: 997861.156945
#          Iterations: 7
#          Function evaluations: 17
#          Gradient evaluations: 17
# Optimization terminated successfully.
#          Current function value: 1001416.599553
#          Iterations: 6
#          Function evaluations: 18
#          Gradient evaluations: 18
# Optimization terminated successfully.
#          Current function value: 1001089.636569
#          Iterations: 6
#          Function evaluations: 14
#          Gradient evaluations: 14
# Optimization terminated successfully.
#          Current function value: 998941.987900
#          Iterations: 6
#          Function evaluations: 16
#          Gradient evaluations: 16
# Optimization terminated successfully.
#          Current function value: 1001081.088839
#          Iterations: 6
#          Function evaluations: 15
#          Gradient evaluations: 15
# Optimization terminated successfully.
#          Current function value: 1000408.540190
#          Iterations: 6
#          Function evaluations: 16
#          Gradient evaluations: 16
# Optimization terminated successfully.
#          Current function value: 999826.394116
#          Iterations: 6
#          Function evaluations: 12
#          Gradient evaluations: 12
# Optimization terminated successfully.
#          Current function value: 998926.992315
#          Iterations: 6
#          Function evaluations: 15
#          Gradient evaluations: 15
# Optimization terminated successfully.
#          Current function value: 998613.057174
#          Iterations: 6
#          Function evaluations: 12
#          Gradient evaluations: 12
# Optimization terminated successfully.
#          Current function value: 1000001.425293
#          Iterations: 6
#          Function evaluations: 13
#          Gradient evaluations: 13
# Optimization terminated successfully.
#          Current function value: 1000441.403176
#          Iterations: 6
#          Function evaluations: 14
#          Gradient evaluations: 14
# Optimization terminated successfully.
#          Current function value: 999087.823608
#          Iterations: 6
#          Function evaluations: 15
#          Gradient evaluations: 15
# Optimization terminated successfully.
#          Current function value: 999430.101326
#          Iterations: 5
#          Function evaluations: 11
#          Gradient evaluations: 11
# Optimization terminated successfully.
#          Current function value: 999857.402963
#          Iterations: 6
#          Function evaluations: 13
#          Gradient evaluations: 13
# Optimization terminated successfully.
#          Current function value: 999528.805252
#          Iterations: 6
#          Function evaluations: 15
#          Gradient evaluations: 15
# Optimization terminated successfully.
#          Current function value: 1001788.213552
#          Iterations: 6
#          Function evaluations: 14
#          Gradient evaluations: 14
# Optimization terminated successfully.
#          Current function value: 1000104.193879
#          Iterations: 6
#          Function evaluations: 16
#          Gradient evaluations: 16
# Optimization terminated successfully.
#          Current function value: 999740.009908
#          Iterations: 6
#          Function evaluations: 14
#          Gradient evaluations: 14
# Optimization terminated successfully.
#          Current function value: 1000556.763718
#          Iterations: 6
#          Function evaluations: 17
#          Gradient evaluations: 17
# Optimization terminated successfully.
#          Current function value: 999543.773041
#          Iterations: 6
#          Function evaluations: 14
#          Gradient evaluations: 14
# Optimization terminated successfully.
#          Current function value: 999008.286791
#          Iterations: 6
#          Function evaluations: 14
#          Gradient evaluations: 14
# Optimization terminated successfully.
#          Current function value: 999119.698690
#          Iterations: 6
#          Function evaluations: 15
#          Gradient evaluations: 15
# Optimization terminated successfully.
#          Current function value: 999237.991394
#          Iterations: 6
#          Function evaluations: 14
#          Gradient evaluations: 14
# Optimization terminated successfully.
#          Current function value: 999016.094756
#          Iterations: 6
#          Function evaluations: 14
#          Gradient evaluations: 14
# Optimization terminated successfully.
#          Current function value: 999588.018708
#          Iterations: 6
#          Function evaluations: 16
#          Gradient evaluations: 16
# Optimization terminated successfully.
#          Current function value: 998321.481715
#          Iterations: 6
#          Function evaluations: 15
#          Gradient evaluations: 15
# Optimization terminated successfully.
#          Current function value: 999851.398277
#          Iterations: 6
#          Function evaluations: 14
#          Gradient evaluations: 14
# Optimization terminated successfully.
#          Current function value: 1004280.846203
#          Iterations: 7
#          Function evaluations: 18
#          Gradient evaluations: 18
# Optimization terminated successfully.
#          Current function value: 996935.011447
#          Iterations: 7
#          Function evaluations: 18
#          Gradient evaluations: 18
# Optimization terminated successfully.
#          Current function value: 1000832.620428
#          Iterations: 6
#          Function evaluations: 14
#          Gradient evaluations: 14
# Optimization terminated successfully.
#          Current function value: 998562.893407
#          Iterations: 7
#          Function evaluations: 17
#          Gradient evaluations: 17
# Optimization terminated successfully.
#          Current function value: 1001468.892750
#          Iterations: 6
#          Function evaluations: 15
#          Gradient evaluations: 15
# Optimization terminated successfully.
#          Current function value: 999336.473572
#          Iterations: 6
#          Function evaluations: 15
#          Gradient evaluations: 15
# Optimization terminated successfully.
#          Current function value: 1001888.190758
#          Iterations: 6
#          Function evaluations: 15
#          Gradient evaluations: 15
# Optimization terminated successfully.
#          Current function value: 999849.639547
#          Iterations: 6
#          Function evaluations: 13
#          Gradient evaluations: 13
# Optimization terminated successfully.
#          Current function value: 998443.289251
#          Iterations: 6
#          Function evaluations: 9
#          Gradient evaluations: 9
# Optimization terminated successfully.
#          Current function value: 1000570.283851
#          Iterations: 6
#          Function evaluations: 14
#          Gradient evaluations: 14
# Optimization terminated successfully.
#          Current function value: 999791.417441
#          Iterations: 6
#          Function evaluations: 14
#          Gradient evaluations: 14
# Optimization terminated successfully.
#          Current function value: 1000069.223471
#          Iterations: 6
#          Function evaluations: 17
#          Gradient evaluations: 17
# Optimization terminated successfully.
#          Current function value: 999702.097728
#          Iterations: 6
#          Function evaluations: 13
#          Gradient evaluations: 13
# Optimization terminated successfully.
#          Current function value: 1001793.456389
#          Iterations: 6
#          Function evaluations: 11
#          Gradient evaluations: 11
# Optimization terminated successfully.
#          Current function value: 1000595.937608
#          Iterations: 6
#          Function evaluations: 14
#          Gradient evaluations: 14
# Optimization terminated successfully.
#          Current function value: 998893.051222
#          Iterations: 6
#          Function evaluations: 15
#          Gradient evaluations: 15
# Optimization terminated successfully.
#          Current function value: 999544.442464
#          Iterations: 7
#          Function evaluations: 18
#          Gradient evaluations: 18
# Optimization terminated successfully.
#          Current function value: 996806.782088
#          Iterations: 6
#          Function evaluations: 13
#          Gradient evaluations: 13
# Optimization terminated successfully.
#          Current function value: 1000836.591663
#          Iterations: 6
#          Function evaluations: 16
#          Gradient evaluations: 16
# Optimization terminated successfully.
#          Current function value: 1000949.381721
#          Iterations: 6
#          Function evaluations: 14
#          Gradient evaluations: 14
# Optimization terminated successfully.
#          Current function value: 1000997.620561
#          Iterations: 7
#          Function evaluations: 20
#          Gradient evaluations: 20
# Optimization terminated successfully.
#          Current function value: 998752.135864
#          Iterations: 6
#          Function evaluations: 15
#          Gradient evaluations: 15
# Optimization terminated successfully.
#          Current function value: 1000149.747434
#          Iterations: 6
#          Function evaluations: 12
#          Gradient evaluations: 12
# Optimization terminated successfully.
#          Current function value: 1001350.887562
#          Iterations: 6
#          Function evaluations: 18
#          Gradient evaluations: 18
# Optimization terminated successfully.
#          Current function value: 1001036.607794
#          Iterations: 7
#          Function evaluations: 18
#          Gradient evaluations: 18
# Optimization terminated successfully.
#          Current function value: 998822.451845
#          Iterations: 6
#          Function evaluations: 16
#          Gradient evaluations: 16
# Optimization terminated successfully.
#          Current function value: 1002044.604955
#          Iterations: 6
#          Function evaluations: 14
#          Gradient evaluations: 14
# Optimization terminated successfully.
#          Current function value: 997665.983184
#          Iterations: 6
#          Function evaluations: 14
#          Gradient evaluations: 14
# Optimization terminated successfully.
#          Current function value: 997671.798389
#          Iterations: 6
#          Function evaluations: 13
#          Gradient evaluations: 13
# Optimization terminated successfully.
#          Current function value: 1002755.689514
#          Iterations: 6
#          Function evaluations: 15
#          Gradient evaluations: 15
# Optimization terminated successfully.
#          Current function value: 1
#          Gradient evaluations: 20
# Optimization terminated successfully.
#          Current function value: 1001423.776584
#          Iterations: 6
#          Function evaluations: 17
#          Gradient evaluations: 17
# Optimization terminated successfully.
#          Current function value: 1001442.867668
#          Iterations: 6
#          Function evaluations: 15
#          Gradient evaluations: 15
# Optimization terminated successfully.
#          Current function value: 998449.484979
#          Iterations: 6
#          Function evaluations: 16
#          Gradient evaluations: 16
# Optimization terminated successfully.
#          Current function value: 999402.078145
#          Iterations: 6
#          Function evaluations: 14
#          Gradient evaluations: 14
# Optimization terminated successfully.
#          Current function value: 1004338.031107
#          Iterations: 6
#          Function evaluations: 14
#          Gradient evaluations: 14
# Optimization terminated successfully.
#          Current function value: 998300.582983
#          Iterations: 6
#          Function evaluations: 14
#          Gradient evaluations: 14
# Optimization terminated successfully.
#          Current function value: 999497.830950
#          Iterations: 6
#          Function evaluations: 13
#          Gradient evaluations: 13
# Optimization terminated successfully.
#          Current function value: 999045.844024
#          Iterations: 6
#          Function evaluations: 14
#          Gradient evaluations: 14
# Optimization terminated successfully.
#          Current function value: 998495.873815
#          Iterations: 6
#          Function evaluations: 15
#          Gradient evaluations: 15
# Optimization terminated successfully.
#          Current function value: 1000247.266786
#          Iterations: 6
#          Function evaluations: 14
#          Gradient evaluations: 14

# %%
data = pd.DataFrame(results)
data.columns = ['rep', 'success', 'aved', 'one', 'two', 'three', 'llv']
data.head()
# Out:
#    rep  success      aved       one       two     three           llv
# 0  1.0      1.0  0.578867 -0.000093  0.000965 -0.000182 -9.976839e+05
# 1  2.0      1.0 -0.095490  0.000651  0.000419 -0.000511 -1.000970e+06
# 2  3.0      1.0  0.545041  0.000446  0.001044  0.000141 -9.985933e+05
# 3  4.0      1.0 -0.750869 -0.000370  0.001705 -0.000579 -1.000220e+06
# 4  5.0      1.0 -2.064396  0.000737 -0.000918 -0.001252 -9.988506e+05

# %%
data1 = data[data['success'] == 1]
data0 = data[data['success'] == 0]

print(data1.describe())
print(data0.describe())
# Out:
#                 rep  success         aved          one          two  \
# count   9620.000000   9620.0  9620.000000  9620.000000  9620.000000
# mean    5002.477755      1.0     0.012997     0.000003    -0.000003
# std     2886.796487      0.0     1.006277     0.001007     0.001006
# min        1.000000      1.0    -3.747690    -0.004405    -0.004021
# 25%     2506.750000      1.0    -0.662369    -0.000669    -0.000683
# 50%     4998.500000      1.0     0.011061     0.000015     0.000005
# 75%     7505.250000      1.0     0.688440     0.000681     0.000672
# max    10000.000000      1.0     4.258833     0.003773     0.003806
#
#              three           llv
# count  9620.000000  9.620000e+03
# mean     -0.000002 -9.999987e+05
# std       0.000996  1.398474e+03
# min      -0.003714 -1.006451e+06
# 25%      -0.000659 -1.000949e+06
# 50%      -0.000009 -9.999937e+05
# 75%       0.000654 -9.990403e+05
# max       0.003937 -9.945357e+05
#                rep  success        aved         one         two       three  \
# count   380.000000    380.0  380.000000  380.000000  380.000000  380.000000
# mean   4950.431579      0.0   -0.024815   -0.000013   -0.000042    0.000048
# std    2892.763247      0.0    0.665759    0.000999    0.000988    0.001006
# min      91.000000      0.0   -2.454456   -0.003489   -0.002513   -0.003097
# 25%    2303.750000      0.0   -0.501642   -0.000695   -0.000664   -0.000642
# 50%    5063.500000      0.0   -0.030473   -0.000012   -0.000040    0.000058
# 75%    7410.500000      0.0    0.492138    0.000629    0.000623    0.000728
# max    9970.000000      0.0    2.622473    0.003094    0.002681    0.003156
#
#                 llv
# count  3.800000e+02
# mean  -9.999427e+05
# std    1.321351e+03
# min   -1.003697e+06
# 25%   -1.000847e+06
# 50%   -9.999075e+05
# 75%   -9.990469e+05
# max   -9.964207e+05
